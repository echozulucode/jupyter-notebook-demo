# %% [markdown]
# # Demo Jupyter Notebook
# This is a test notebook for first learning to use Jupyter notebooks in general and specifically within VSCode.

# %%
name: str = 'Eric'
print(f'Hello {name}')
# Out:
# Hello Eric

# %% [markdown]
# ## Links
# - [Markdown Cheat Sheet](https://www.markdownguide.org/cheat-sheet/)

# %% [markdown]
# ## MathJax-Aware
#
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}
#
# \begin{equation*}
# \left( \sum_{k=1}^n a_k b_k \right)^2 \leq \left( \sum_{k=1}^n a_k^2 \right) \left( \sum_{k=1}^n b_k^2 \right)
# \end{equation*}
#
# \begin{equation*}
# P(E)   = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}
#
# This expression $\sqrt{3x-1}+(1+x)^2$ is an example of a TeX inline equation in a [Markdown-formatted](https://daringfireball.net/projects/markdown/) sentence.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
mu = 0
std = 1
x = np.linspace(start=-4, stop=4, num=100)
y = stats.norm.pdf(x, mu, std) 
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 5, 100)
plt.plot(x, np.sin(x), 'c--', linewidth=3)
plt.grid(b=True, color='aqua', alpha=0.3, linestyle='-.', linewidth=2)
plt.show()
# Out:
# C:\Users\ericj\AppData\Local\Temp/ipykernel_29084/1278436532.py:7: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, color='aqua', alpha=0.3, linestyle='-.', linewidth=2)
